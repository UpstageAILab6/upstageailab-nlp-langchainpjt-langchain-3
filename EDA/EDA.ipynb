# %% [markdown]
# ## 데이터 불러오기

# %%
import json
from pathlib import Path

# 📁 현재 노트북 위치 기준으로 상대 경로 설정
data_path = Path("data/combined_service_data.json")

# 📄 JSON 로드
with open(data_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ 개수 확인
print(f"📦 전체 서비스 개수: {len(data)}개")
# Out:
# 📦 전체 서비스 개수: 26573개

# %% [markdown]
# ## 중복 확인
# ### 서비스명 동일, ID 확인

# %%
import json
from collections import defaultdict, Counter
from pathlib import Path

# 경로 설정 및 JSON 로드
data_path = Path("data/combined_service_data.json")
with open(data_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 1. 서비스명 → 서비스ID 리스트로 매핑
name_to_ids = defaultdict(list)
for item in data:
    name = item.get("서비스명")
    sid = item.get("서비스ID")
    name_to_ids[name].append(sid)

# 2. 중복된 서비스명만 추출
duplicates = {name: sids for name, sids in name_to_ids.items() if len(sids) > 1}

# 3. 결과 출력
print(f"❗ 중복된 서비스명 개수: {len(duplicates)}개\n")

for name, sids in list(duplicates.items())[:10]:  # 예시 10개만 출력
    print(f"🔁 서비스명: {name}")
    print("   서비스ID 목록:", sids)
    print()
# Out:
# ❗ 중복된 서비스명 개수: 483개
#
# 🔁 서비스명: 양식장 친환경에너지 보급
#    서비스ID 목록: ['119200000126', '119200000126', '502000000229', '502000000229']
#
# 🔁 서비스명: 수산식품 가공설비 지원
#    서비스ID 목록: ['119200000143', '119200000143', '493000000110', '493000000110']
#
# 🔁 서비스명: 긴급돌봄 지원
#    서비스ID 목록: ['135200005026', '135200005026', 'O00012100001', 'O00012100001']
#
# 🔁 서비스명: 석면피해 구제급여 지급
#    서비스ID 목록: ['148000000001', '148000000001', '148000000001', '148000000001', '482000000122', '482000000122', '482000000122', '482000000122', '499000000113', '499000000113', '499000000113', '499000000113', '568000000104', '568000000104', '568000000104', '568000000104']
#
# 🔁 서비스명: 유기농업자재 지원
#    서비스ID 목록: ['154300000014', '154300000014', '485000000116', '485000000116']
#
# 🔁 서비스명: 곤충산업 육성 지원
#    서비스ID 목록: ['154300005006', '154300005006', '644000000236', '644000000236']
#
# 🔁 서비스명: 청년월세 한시 특별지원
#    서비스ID 목록: ['161300000099', '161300000099', '452000000319', '452000000319']
#
# 🔁 서비스명: LPG용기 사용가구 시설개선 지원
#    서비스ID 목록: ['174100000020', '174100000020', '174100000020', '484000000383', '484000000383', '484000000383', '626000000146', '626000000146', '626000000146']
#
# 🔁 서비스명: 임산부 건강관리 지원
#    서비스ID 목록: ['300000000101', '300000000101', '300000000101', '300000000101', '304000000127', '304000000127', '304000000127', '304000000127', '472000000109', '472000000109', '472000000109', '472000000109', '567000000125', '567000000125', '567000000125', '567000000125']
#
# 🔁 서비스명: 저소득주민 국민건강보험료 지원
#    서비스ID 목록: ['300000000102', '300000000102', '300000000102', '300000000102', '300000000102', '300000000102', '300000000102', '300000000102', '316000000121', '316000000121', '316000000121', '316000000121', '316000000121', '316000000121', '316000000121', '316000000121', '319000000106', '319000000106', '319000000106', '319000000106', '319000000106', '319000000106', '319000000106', '319000000106', '351050000109', '351050000109', '351050000109', '351050000109', '351050000109', '351050000109', '351050000109', '351050000109', '354000000105', '354000000105', '354000000105', '354000000105', '354000000105', '354000000105', '354000000105', '354000000105', '419000000119', '419000000119', '419000000119', '419000000119', '419000000119', '419000000119', '419000000119', '419000000119', '439000000833', '439000000833', '439000000833', '439000000833', '439000000833', '439000000833', '439000000833', '439000000833', '470000000111', '470000000111', '470000000111', '470000000111', '470000000111', '470000000111', '470000000111', '470000000111']

# %% [markdown]
# ### 서비스ID 동일 서비스명 확인

# %%
import json
from collections import defaultdict, Counter
from pathlib import Path

# 경로 설정 및 JSON 로드
data_path = Path("data/combined_service_data.json")
with open(data_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 1. 서비스ID → 서비스명 리스트로 매핑
id_to_names = defaultdict(list)
for item in data:
    sid = item.get("서비스ID")
    name = item.get("서비스명")
    id_to_names[sid].append(name)

# 2. 중복된 서비스ID만 추출
duplicates = {sid: names for sid, names in id_to_names.items() if len(names) > 1}

# 3. 결과 출력
print(f"❗ 중복된 서비스ID 개수: {len(duplicates)}개\n")

for sid, names in list(duplicates.items())[:10]:  # 예시 10개만 출력
    print(f"🔁 서비스ID: {sid}")
    print("   서비스명 목록:", names)
    print()
# Out:
# ❗ 중복된 서비스ID 개수: 1878개
#
# 🔁 서비스ID: 119200000126
#    서비스명 목록: ['양식장 친환경에너지 보급', '양식장 친환경에너지 보급']
#
# 🔁 서비스ID: 119200000143
#    서비스명 목록: ['수산식품 가공설비 지원', '수산식품 가공설비 지원']
#
# 🔁 서비스ID: 135200005026
#    서비스명 목록: ['긴급돌봄 지원', '긴급돌봄 지원']
#
# 🔁 서비스ID: 148000000001
#    서비스명 목록: ['석면피해 구제급여 지급', '석면피해 구제급여 지급', '석면피해 구제급여 지급', '석면피해 구제급여 지급']
#
# 🔁 서비스ID: 154300000014
#    서비스명 목록: ['유기농업자재 지원', '유기농업자재 지원']
#
# 🔁 서비스ID: 154300005006
#    서비스명 목록: ['곤충산업 육성 지원', '곤충산업 육성 지원']
#
# 🔁 서비스ID: 161300000099
#    서비스명 목록: ['청년월세 한시 특별지원', '청년월세 한시 특별지원']
#
# 🔁 서비스ID: 174100000020
#    서비스명 목록: ['LPG용기 사용가구 시설개선 지원', 'LPG용기 사용가구 시설개선 지원', 'LPG용기 사용가구 시설개선 지원']
#
# 🔁 서비스ID: 300000000101
#    서비스명 목록: ['임산부 건강관리 지원', '임산부 건강관리 지원', '임산부 건강관리 지원', '임산부 건강관리 지원']
#
# 🔁 서비스ID: 300000000102
#    서비스명 목록: ['저소득주민 국민건강보험료 지원', '저소득주민 국민건강보험료 지원', '저소득주민 국민건강보험료 지원', '저소득주민 국민건강보험료 지원', '저소득주민 국민건강보험료 지원', '저소득주민 국민건강보험료 지원', '저소득주민 국민건강보험료 지원', '저소득주민 국민건강보험료 지원']

# %% [markdown]
# ### 서비스명 동일한 item 모두 보기

# %%
import json
from pathlib import Path

# JSON 로드
data_path = Path("data/combined_service_data.json")
with open(data_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 특정 서비스명으로 필터링
target_name = "석면피해 구제급여 지급"
matching_items = [item for item in data if item.get("서비스명") == target_name]

# 결과 출력
print(f"🔍 '{target_name}' 관련 항목 수: {len(matching_items)}개\n")

for i, item in enumerate(matching_items, 1):
    print(f"📦 항목 {i} (서비스ID: {item.get('서비스ID')})")
    print(json.dumps(item, ensure_ascii=False, indent=2))
    print("="*80)
# Out:
# 🔍 '석면피해 구제급여 지급' 관련 항목 수: 16개
#
# 📦 항목 1 (서비스ID: 148000000001)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 0,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 2 (서비스ID: 148000000001)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 3 (서비스ID: 148000000001)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 4 (서비스ID: 148000000001)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 18,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 5 (서비스ID: 482000000122)
# {
#   "구비서류": null,
#   "문의처": "순천시청 환경관리과/061-749-5777",
#   "법령": "석면피해구제법",
#   "서비스ID": "482000000122",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 순천시",
#   "수정일시": "2025-01-31",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
#   "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 0,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 6 (서비스ID: 482000000122)
# {
#   "구비서류": null,
#   "문의처": "순천시청 환경관리과/061-749-5777",
#   "법령": "석면피해구제법",
#   "서비스ID": "482000000122",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 순천시",
#   "수정일시": "2025-01-31",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
#   "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 7 (서비스ID: 482000000122)
# {
#   "구비서류": null,
#   "문의처": "순천시청 환경관리과/061-749-5777",
#   "법령": "석면피해구제법",
#   "서비스ID": "482000000122",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 순천시",
#   "수정일시": "2025-01-31",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
#   "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 8 (서비스ID: 482000000122)
# {
#   "구비서류": null,
#   "문의처": "순천시청 환경관리과/061-749-5777",
#   "법령": "석면피해구제법",
#   "서비스ID": "482000000122",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 순천시",
#   "수정일시": "2025-01-31",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
#   "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 18,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 9 (서비스ID: 499000000113)
# {
#   "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#   "문의처": "환경수질관리과/061-550-5503",
#   "법령": "석면피해구제법(제10조, 제2항)",
#   "서비스ID": "499000000113",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자에게 의료비 보조금 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 완도군",
#   "수정일시": "2025-01-22",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
#   "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 0,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 10 (서비스ID: 499000000113)
# {
#   "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#   "문의처": "환경수질관리과/061-550-5503",
#   "법령": "석면피해구제법(제10조, 제2항)",
#   "서비스ID": "499000000113",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자에게 의료비 보조금 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 완도군",
#   "수정일시": "2025-01-22",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
#   "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 11 (서비스ID: 499000000113)
# {
#   "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#   "문의처": "환경수질관리과/061-550-5503",
#   "법령": "석면피해구제법(제10조, 제2항)",
#   "서비스ID": "499000000113",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자에게 의료비 보조금 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 완도군",
#   "수정일시": "2025-01-22",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
#   "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 12 (서비스ID: 499000000113)
# {
#   "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#   "문의처": "환경수질관리과/061-550-5503",
#   "법령": "석면피해구제법(제10조, 제2항)",
#   "서비스ID": "499000000113",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면 피해자에게 의료비 보조금 지급",
#   "선정기준": null,
#   "소관기관명": "전라남도 완도군",
#   "수정일시": "2025-01-22",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
#   "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 18,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 13 (서비스ID: 568000000104)
# {
#   "구비서류": null,
#   "문의처": "당진시 자원순환과/041-350-4332",
#   "법령": "석면피해구제법||석면피해구제법(제17조)",
#   "서비스ID": "568000000104",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": null,
#   "선정기준": null,
#   "소관기관명": "충청남도 당진시",
#   "수정일시": "2025-01-23",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
#   "지원대상": "○ 석면피해자 및 피해자 유족",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 0,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 14 (서비스ID: 568000000104)
# {
#   "구비서류": null,
#   "문의처": "당진시 자원순환과/041-350-4332",
#   "법령": "석면피해구제법||석면피해구제법(제17조)",
#   "서비스ID": "568000000104",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": null,
#   "선정기준": null,
#   "소관기관명": "충청남도 당진시",
#   "수정일시": "2025-01-23",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
#   "지원대상": "○ 석면피해자 및 피해자 유족",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 15 (서비스ID: 568000000104)
# {
#   "구비서류": null,
#   "문의처": "당진시 자원순환과/041-350-4332",
#   "법령": "석면피해구제법||석면피해구제법(제17조)",
#   "서비스ID": "568000000104",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": null,
#   "선정기준": null,
#   "소관기관명": "충청남도 당진시",
#   "수정일시": "2025-01-23",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
#   "지원대상": "○ 석면피해자 및 피해자 유족",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 16 (서비스ID: 568000000104)
# {
#   "구비서류": null,
#   "문의처": "당진시 자원순환과/041-350-4332",
#   "법령": "석면피해구제법||석면피해구제법(제17조)",
#   "서비스ID": "568000000104",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": null,
#   "선정기준": null,
#   "소관기관명": "충청남도 당진시",
#   "수정일시": "2025-01-23",
#   "신청기한": "상시신청",
#   "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
#   "지원대상": "○ 석면피해자 및 피해자 유족",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 18,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================

# %% [markdown]
# ### 서비스ID 동일한 item 모두 보기

# %%
import json
from pathlib import Path

# JSON 로드
data_path = Path("data/combined_service_data.json")
with open(data_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 특정 서비스ID로 필터링
target_id = "148000000001"  # 여기에 원하는 서비스ID 입력
matching_items = [item for item in data if item.get("서비스ID") == target_id]

# 결과 출력
print(f"🔍 서비스ID '{target_id}' 관련 항목 수: {len(matching_items)}개\n")

for i, item in enumerate(matching_items, 1):
    print(f"📦 항목 {i} (서비스명: {item.get('서비스명')})")
    print(json.dumps(item, ensure_ascii=False, indent=2))
    print("="*80)
# Out:
# 🔍 서비스ID '148000000001' 관련 항목 수: 4개
#
# 📦 항목 1 (서비스명: 석면피해 구제급여 지급)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 0,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 2 (서비스명: 석면피해 구제급여 지급)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 3 (서비스명: 석면피해 구제급여 지급)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 19,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 📦 항목 4 (서비스명: 석면피해 구제급여 지급)
# {
#   "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#   "문의처": "석면피해구제시스템/1833-7690",
#   "법령": "석면피해구제법(제16조)",
#   "서비스ID": "148000000001",
#   "서비스명": "석면피해 구제급여 지급",
#   "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
#   "선정기준": "지원대상과 동일",
#   "소관기관명": "환경부",
#   "수정일시": "2025-01-24",
#   "신청기한": "상시신청",
#   "신청방법": "관할 시군구청(환경부서)에 신청",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청",
#   "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
#   "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 18,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================

# %% [markdown]
# ### 서비스명 동일한 item 비교

# %%
import json
from pathlib import Path
from itertools import combinations
import difflib

# 데이터 로드
data_path = Path("data/combined_service_data.json")
with open(data_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# ✅ 비교 대상 서비스명
target_name = "석면피해 구제급여 지급"

# 1. 해당 서비스명으로 필터링
matched_items = [item for item in data if item.get("서비스명") == target_name]
print(f"🔍 '{target_name}' 관련 항목 수: {len(matched_items)}개")

# 2. JSON 문자열로 정렬해서 비교 준비
serialized = [json.dumps(item, sort_keys=True, ensure_ascii=False, indent=2).splitlines() for item in matched_items]

# 3. 모든 쌍 비교
for (i, j) in combinations(range(len(serialized)), 2):
    if serialized[i] != serialized[j]:
        print(f"\n❗ 항목 {i}와 항목 {j}는 서로 다릅니다.")
        diff = difflib.unified_diff(
            serialized[i],
            serialized[j],
            fromfile=f'항목 {i}',
            tofile=f'항목 {j}',
            lineterm=''
        )
        print("\n".join(diff))
    else:
        print(f"✅ 항목 {i}와 항목 {j}는 동일합니다.")
# Out:
# 🔍 '석면피해 구제급여 지급' 관련 항목 수: 16개
#
# ❗ 항목 0와 항목 1는 서로 다릅니다.
# --- 항목 0
# +++ 항목 1
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
#    "문의처": "석면피해구제시스템/1833-7690",
#
# ❗ 항목 0와 항목 2는 서로 다릅니다.
# --- 항목 0
# +++ 항목 2
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
#    "문의처": "석면피해구제시스템/1833-7690",
#
# ❗ 항목 0와 항목 3는 서로 다릅니다.
# --- 항목 0
# +++ 항목 3
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 18,
#      "종료": 120
#    },
#    "문의처": "석면피해구제시스템/1833-7690",
#
# ❗ 항목 0와 항목 4는 서로 다릅니다.
# --- 항목 0
# +++ 항목 4
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 5는 서로 다릅니다.
# --- 항목 0
# +++ 항목 5
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 6는 서로 다릅니다.
# --- 항목 0
# +++ 항목 6
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 7는 서로 다릅니다.
# --- 항목 0
# +++ 항목 7
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 8는 서로 다릅니다.
# --- 항목 0
# +++ 항목 8
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
#      "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 9는 서로 다릅니다.
# --- 항목 0
# +++ 항목 9
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 10는 서로 다릅니다.
# --- 항목 0
# +++ 항목 10
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 11는 서로 다릅니다.
# --- 항목 0
# +++ 항목 11
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 12는 서로 다릅니다.
# --- 항목 0
# +++ 항목 12
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 13는 서로 다릅니다.
# --- 항목 0
# +++ 항목 13
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 14는 서로 다릅니다.
# --- 항목 0
# +++ 항목 14
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 0와 항목 15는 서로 다릅니다.
# --- 항목 0
# +++ 항목 15
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
# ✅ 항목 1와 항목 2는 동일합니다.
#
# ❗ 항목 1와 항목 3는 서로 다릅니다.
# --- 항목 1
# +++ 항목 3
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
#    "문의처": "석면피해구제시스템/1833-7690",
#
# ❗ 항목 1와 항목 4는 서로 다릅니다.
# --- 항목 1
# +++ 항목 4
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 5는 서로 다릅니다.
# --- 항목 1
# +++ 항목 5
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 6는 서로 다릅니다.
# --- 항목 1
# +++ 항목 6
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 7는 서로 다릅니다.
# --- 항목 1
# +++ 항목 7
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "순천시청 환경관리과/061-749-5777",
# +  "법령": "석면피해구제법",
# +  "서비스ID": "482000000122",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자 및 유족에게 구제급여 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 순천시",
# +  "수정일시": "2025-01-31",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n\r\n1. 지자체 방문접수\r\n - 신청서 작성 및 구비서류 첨부\r\n↓\r\n2. 한국환경산업기술원 인정신청서 접수\r\n - 청구서류 검토\r\n - 석면피해판정위원회 심의\r\n - 석면피해인정여부 및 피해등급 결정\r\n↓ \r\n3. 지자체 및 신청인 인정여부 통지",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면으로 건강피해를 입은 피해자(유족)에게 구제급여 지급",
# +  "지원대상": "○ 석면피해판정위원회에서 인정을 받은 석면건강피해자(또는 유족)",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 8는 서로 다릅니다.
# --- 항목 1
# +++ 항목 8
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 9는 서로 다릅니다.
# --- 항목 1
# +++ 항목 9
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 10는 서로 다릅니다.
# --- 항목 1
# +++ 항목 10
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 11는 서로 다릅니다.
# --- 항목 1
# +++ 항목 11
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "환경수질관리과/061-550-5503",
# +  "법령": "석면피해구제법(제10조, 제2항)",
# +  "서비스ID": "499000000113",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "선정기준": null,
# +  "소관기관명": "전라남도 완도군",
# +  "수정일시": "2025-01-22",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# +  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 12는 서로 다릅니다.
# --- 항목 1
# +++ 항목 12
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 13는 서로 다릅니다.
# --- 항목 1
# +++ 항목 13
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 14는 서로 다릅니다.
# --- 항목 1
# +++ 항목 14
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 1와 항목 15는 서로 다릅니다.
# --- 항목 1
# +++ 항목 15
# @@ -1,22 +1,22 @@
#  {
# -  "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "석면피해구제시스템/1833-7690",
# -  "법령": "석면피해구제법(제16조)",
# -  "서비스ID": "148000000001",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면으로 인한 건강피해자 및 유족에게 구제급여를 지급함으로 석면으로 인한 건강 피해를 신속하고 공정하게 구제",
# -  "선정기준": "지원대상과 동일",
# -  "소관기관명": "환경부",
# -  "수정일시": "2025-01-24",
# +  "서비스목적": null,
# +  "선정기준": null,
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "관할 시군구청(환경부서)에 신청",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
# -  "접수기관명": "시·군·구청",
# +  "접수기관명": null,
#    "조건": {
#      "1인가구": true,
#      "남성": true,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 요양급여 :치료에 소요되는 비용중 급여항목의 일부본인부담금 지원(매월 지급)\r\n\r\n○ 요양 생활수당 : 요양급여 외 석면 질병의 치료·요양 및 생활에 필요한 경비(매월 지급)\r\n\r\n○  장례비 : 피 인정자가 석면 질병으로 사망한 경우 그 장례를 지낸 유족에게 지급\r\n\r\n○ 특별유족 조의금 및 특별장례비 : 법 시행일 전 석면 질병으로 사망한 사람, 신청하지 아니하고, 법 시행 후 석면 질병으로 사망한 사람, 신청하였으나 인정받기 전에 석면 질병으로 사망한 사람 유족에게 지급\r\n\r\n○ 구제급여조정금 : 피 인정자가 해당 석면 질병으로 사망한 경우 해당 석면 질병에 관하여 받은 요양급여와 요양 생활수당의 합계액이 특별유족조위금의 액수보다 적은 때 지급",
# -  "지원대상": "○ 구제 대상자 : 석면으로 인한 건강피해자 및 유족\r\n\r\n○ 대상 질병 : 원발성 악성중피종, 원발성 폐암, 석면폐증",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 2와 항목 3는 서로 다릅니다.
# --- 항목 2
# +++ 항목 3
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": "○ 석면 피해 인정 신청서\r\n - 석면 노출 정도 확인 질문서(신청인의 주민등록표 초본, 신청인의 근무경력증명서 또는 근무경력 확인서류)\r\n - 개인정보보호법에 따른 개인 정보 수집 이용 및 제공동의서\r\n - 신청인 확인서류(주민등록등본)\r\n - 석면 질병별 증빙서류(진단서 및 조직 병리 검사 결과서 등)\r\n\r\n○ 대리인 확인서류\r\n - 직계가족 : 대리인 신분증, 가족 관계 증명 서류\r\n - 직계가족이 아닌 경우 : 대리인 신분증, 신청인 인감증명서, 위임장",
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
#    "문의처": "석면피해구제시스템/1833-7690",
#
# ❗ 항목 2와 항목 4는 서로 다릅니다.
# --- 항목 2
# +++ 항목 4
# ...
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 9와 항목 13는 서로 다릅니다.
# --- 항목 9
# +++ 항목 13
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 9와 항목 14는 서로 다릅니다.
# --- 항목 9
# +++ 항목 14
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 9와 항목 15는 서로 다릅니다.
# --- 항목 9
# +++ 항목 15
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 10와 항목 11는 서로 다릅니다.
# --- 항목 10
# +++ 항목 11
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
#    "문의처": "환경수질관리과/061-550-5503",
#
# ❗ 항목 10와 항목 12는 서로 다릅니다.
# --- 항목 10
# +++ 항목 12
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 10와 항목 13는 서로 다릅니다.
# --- 항목 10
# +++ 항목 13
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 10와 항목 14는 서로 다릅니다.
# --- 항목 10
# +++ 항목 14
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 10와 항목 15는 서로 다릅니다.
# --- 항목 10
# +++ 항목 15
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 11와 항목 12는 서로 다릅니다.
# --- 항목 11
# +++ 항목 12
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 18,
# +    "시작": 0,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 11와 항목 13는 서로 다릅니다.
# --- 항목 11
# +++ 항목 13
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 18,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 11와 항목 14는 서로 다릅니다.
# --- 항목 11
# +++ 항목 14
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
# -    "시작": 18,
# +    "시작": 19,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 11와 항목 15는 서로 다릅니다.
# --- 항목 11
# +++ 항목 15
# @@ -1,19 +1,19 @@
#  {
# -  "구비서류": "○ 신청인 제출서류\r\n  - 병원비 영수증\r\n  - 가족관계증명서(필요시)\r\n  - 의사 진단서 또는 의사 소견서\r\n\r\n○ 공무원 확인가능 서류(신청인 미제출 서류)\r\n  - 주민등록 등.초본",
# +  "구비서류": null,
#    "대상연령": {
#      "시작": 18,
#      "종료": 120
#    },
# -  "문의처": "환경수질관리과/061-550-5503",
# -  "법령": "석면피해구제법(제10조, 제2항)",
# -  "서비스ID": "499000000113",
# +  "문의처": "당진시 자원순환과/041-350-4332",
# +  "법령": "석면피해구제법||석면피해구제법(제17조)",
# +  "서비스ID": "568000000104",
#    "서비스명": "석면피해 구제급여 지급",
# -  "서비스목적": "석면 피해자에게 의료비 보조금 지급",
# +  "서비스목적": null,
#    "선정기준": null,
# -  "소관기관명": "전라남도 완도군",
# -  "수정일시": "2025-01-22",
# +  "소관기관명": "충청남도 당진시",
# +  "수정일시": "2025-01-23",
#    "신청기한": "상시신청",
# -  "신청방법": "○ 방문 신청\r\n - 시군구 : 완도군청 환경수질관리과 방문 신청\r\n\r\n○ 기타\r\n - fax 신청(061-550-6959)\r\n - 우편 신청(전남 완도군 완도읍 농공단지7길 44, 환경수질관리과)",
# +  "신청방법": "○ 방문 신청\r\n - 시군구 : 당진시청 자원순환과 방문 신청",
#    "온라인신청사이트URL": null,
#    "자치법규": null,
#    "접수기관명": null,
# @@ -36,8 +36,8 @@
#      "해당사항없음": true,
#      "확대가족": true
#    },
# -  "지원내용": "○ 석면피해로 인해 폐질환이 발생한 대상자에게 의료 보조금 지급\r\n - 최대 154.8만원/달",
# -  "지원대상": "○ 주민등록상 완도군에 주소를 둔 자중에 석면피해로 인해 폐질환이 발생한 대상자",
# +  "지원내용": "○ 석면피해인정자에 대한 구제급여(요양급여, 생활수당, 장의금 등) 지급",
# +  "지원대상": "○ 석면피해자 및 피해자 유족",
#    "지원유형": "현금",
#    "행정규칙": null
#  }
#
# ❗ 항목 12와 항목 13는 서로 다릅니다.
# --- 항목 12
# +++ 항목 13
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
#    "문의처": "당진시 자원순환과/041-350-4332",
#
# ❗ 항목 12와 항목 14는 서로 다릅니다.
# --- 항목 12
# +++ 항목 14
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 19,
#      "종료": 120
#    },
#    "문의처": "당진시 자원순환과/041-350-4332",
#
# ❗ 항목 12와 항목 15는 서로 다릅니다.
# --- 항목 12
# +++ 항목 15
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": null,
#    "대상연령": {
# -    "시작": 0,
# +    "시작": 18,
#      "종료": 120
#    },
#    "문의처": "당진시 자원순환과/041-350-4332",
# ✅ 항목 13와 항목 14는 동일합니다.
#
# ❗ 항목 13와 항목 15는 서로 다릅니다.
# --- 항목 13
# +++ 항목 15
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
#    "문의처": "당진시 자원순환과/041-350-4332",
#
# ❗ 항목 14와 항목 15는 서로 다릅니다.
# --- 항목 14
# +++ 항목 15
# @@ -1,7 +1,7 @@
#  {
#    "구비서류": null,
#    "대상연령": {
# -    "시작": 19,
# +    "시작": 18,
#      "종료": 120
#    },
#    "문의처": "당진시 자원순환과/041-350-4332",

# %% [markdown]
# ### 서비스ID 동일한 item 비교

# %%
import json
from pathlib import Path

# 경로 설정 및 데이터 로드
data_path = Path("data/combined_service_data.json")
with open(data_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# 1. 특정 서비스ID로 필터링
target_id = "148000000001"
matched_items = [item for item in data if item.get("서비스ID") == target_id]

print(f"🔍 해당 서비스ID({target_id})로 검색된 항목 수: {len(matched_items)}개")

# 2. 비교: 첫 번째 항목 기준으로 다른 항목들과 비교
base = json.dumps(matched_items[0], sort_keys=True, ensure_ascii=False)

for idx, item in enumerate(matched_items[1:], start=1):
    current = json.dumps(item, sort_keys=True, ensure_ascii=False)

    if base != current:
        print(f"\n❗ 항목 0과 항목 {idx}는 서로 다릅니다.")

        # 글자 단위 비교
        for i, (a, b) in enumerate(zip(base, current)):
            if a != b:
                print(f"  🔹 첫 차이점 at index {i}: '{a}' ≠ '{b}'")
                print(f"  🔎 기준 문자열 일부: {base[i-20:i+20]}")
                print(f"  🔎 비교 문자열 일부: {current[i-20:i+20]}")
                break  # 첫 차이만 확인
    else:
        print(f"✅ 항목 0과 항목 {idx}는 완전히 동일합니다.")
# Out:
# 🔍 해당 서비스ID(148000000001)로 검색된 항목 수: 4개
#
# ❗ 항목 0과 항목 1는 서로 다릅니다.
#   🔹 첫 차이점 at index 303: '0' ≠ '1'
#   🔎 기준 문자열 일부: 임장", "대상연령": {"시작": 0, "종료": 120}, "문의처"
#   🔎 비교 문자열 일부: 임장", "대상연령": {"시작": 19, "종료": 120}, "문의처
#
# ❗ 항목 0과 항목 2는 서로 다릅니다.
#   🔹 첫 차이점 at index 303: '0' ≠ '1'
#   🔎 기준 문자열 일부: 임장", "대상연령": {"시작": 0, "종료": 120}, "문의처"
#   🔎 비교 문자열 일부: 임장", "대상연령": {"시작": 19, "종료": 120}, "문의처
#
# ❗ 항목 0과 항목 3는 서로 다릅니다.
#   🔹 첫 차이점 at index 303: '0' ≠ '1'
#   🔎 기준 문자열 일부: 임장", "대상연령": {"시작": 0, "종료": 120}, "문의처"
#   🔎 비교 문자열 일부: 임장", "대상연령": {"시작": 18, "종료": 120}, "문의처

# %% [markdown]
# ### 모든 경우의 수 비교
# 🔍 서비스ID & 서비스명 같지만 내용이 다른 경우:
# 🔍 서비스ID 같지만 서비스명이 다른 경우:
# 🔍 서비스명 같지만 서비스ID가 다른 경우:

# %%
import json
from collections import defaultdict
from pathlib import Path



# dict: 서비스ID -> item 전체
id_to_items = defaultdict(list)
for item in data:
    sid = item.get("서비스ID")
    id_to_items[sid].append(item)

# dict: 서비스명 -> 서비스ID 리스트
name_to_ids = defaultdict(list)
for item in data:
    name_to_ids[item["서비스명"]].append(item["서비스ID"])

# -----------------------------
# 1️⃣ 서비스ID는 같고 서비스명도 같지만 내용이 다른 경우
# -----------------------------
diff_content_same_id = []
for sid, items in id_to_items.items():
    if len(items) > 1:
        base = json.dumps(items[0], sort_keys=True, ensure_ascii=False)
        for other in items[1:]:
            if json.dumps(other, sort_keys=True, ensure_ascii=False) != base:
                diff_content_same_id.append(sid)
                break

print(f"🔍 서비스ID & 서비스명 같지만 내용이 다른 경우: {len(diff_content_same_id)}개")

# -----------------------------
# 2️⃣ 서비스ID는 같은데 서비스명이 다른 경우
# -----------------------------
diff_name_same_id = []
for sid, items in id_to_items.items():
    names = {item.get("서비스명") for item in items}
    if len(names) > 1:
        diff_name_same_id.append((sid, list(names)))

print(f"🔍 서비스ID 같지만 서비스명이 다른 경우: {len(diff_name_same_id)}개")

# -----------------------------
# 3️⃣ 서비스명은 같은데 서비스ID가 다른 경우
# -----------------------------
same_name_diff_id = []
for name, sids in name_to_ids.items():
    if len(set(sids)) > 1:
        same_name_diff_id.append((name, list(set(sids))))

print(f"🔍 서비스명 같지만 서비스ID가 다른 경우: {len(same_name_diff_id)}개")
# Out:
# 🔍 서비스ID & 서비스명 같지만 내용이 다른 경우: 1507개
# 🔍 서비스ID 같지만 서비스명이 다른 경우: 0개
# 🔍 서비스명 같지만 서비스ID가 다른 경우: 483개

# %% [markdown]
# ## ✅ 서비스 통합 기준 및 방식 정리
#
# 위에서 서비스ID가 같지만 서비스명이 다른 경우는 존재하지 않았기 때문에 통합은 서비스명을 기준으로 하는 것이 가장 좋아 보임.
#
# | 구분 | 조건 | 처리 방식 | 통합 방식 상세 |
# |------|------|------------|----------------|
# | 1. 완전 중복 제거 | `서비스명`, `서비스ID`, 내용이 모두 동일 | 하나만 유지, 나머지 제거 | 중복 항목 제거 (내용까지 완전히 동일한 경우) |
# | 2. `서비스명`, `서비스ID`는 같지만 세부 내용 다름 | 동일한 서비스로 판단 | 하나로 병합 | - 대표 ID와 이름 그대로 유지<br>- `조건` 필드만 다르면 조건 병합<br>- 다른 필드도 다를 경우, 문자열은 `||`로 병합, dict는 키 단위 병합 |
# | 3. 서비스명 동일, 서비스ID 다름 | 동일한 서비스로 판단 | 하나의 항목으로 병합 | - 대표 ID는 첫 번째 항목의 `서비스ID`로 설정<br>- 문자열 필드: 서로 다르면 `||`로 병합<br>- 리스트: 중복 제거 후 병합<br>- `dict` (예: `조건`, `대상연령`): key 기준 병합<br>- 숫자 범위 (`대상연령` 등): min/max로 병합 |

# %%
import json                           # JSON 데이터를 다루기 위한 모듈
from collections import defaultdict   # 기본값이 있는 dict 생성용
from pathlib import Path              # 경로 관리를 위한 Path 객체
from copy import deepcopy             # 객체 깊은 복사용 모듈

# JSON 파일을 열고 데이터 로드
with open("data/combined_service_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)              # JSON 파일을 Python 객체로 로드

# 중복 제거를 위한 집합 및 결과 리스트 초기화
seen = set()                         # (서비스ID, 서비스명, 전체내용)을 저장할 set
deduped = []                         # 중복 제거된 결과 저장 리스트

# 완전 동일 항목 제거 (서비스ID, 서비스명, 내용까지 완전히 동일)
for item in data:
    key = (item["서비스ID"], item["서비스명"])                       # 서비스ID와 서비스명을 묶어서 키 생성
    serialized = json.dumps(item, sort_keys=True, ensure_ascii=False) # 항목 전체를 문자열로 변환하여 비교
    if (key, serialized) not in seen:                                # 중복되지 않았다면
        seen.add((key, serialized))                                  # 집합에 추가
        deduped.append(item)                                         # 결과 리스트에 추가

# 서비스명을 기준으로 항목들을 그룹화
name_to_items = defaultdict(list)      # 서비스명을 키로 하는 딕셔너리 생성
for item in deduped:
    name_to_items[item["서비스명"]].append(item)   # 서비스명 기준으로 리스트에 항목 추가

# 여러 개의 항목을 병합하는 함수 정의
def merge_items(items):
    base = deepcopy(items[0])          # 첫 번째 항목을 기준으로 병합 (깊은 복사)
    for other in items[1:]:            # 두 번째 항목부터 반복
        for key, val in other.items(): # 각 키-값에 대해
            if key not in base or base[key] == val: # 값이 동일하거나 없으면 패스
                continue
            if isinstance(val, str) and isinstance(base[key], str): # 문자열 타입일 경우
                parts = set(base[key].split("||")) | set(val.split("||")) # 중복 제거한 집합 생성
                base[key] = "||".join(sorted(parts))              # 다시 || 로 연결
            elif isinstance(val, list) and isinstance(base[key], list): # 리스트일 경우
                base[key] = list(set(base[key]) | set(val))       # 집합으로 병합 후 리스트 변환
            elif isinstance(val, dict) and isinstance(base[key], dict): # 딕셔너리일 경우
                merged = base[key].copy()                         # 기준값 복사
                for k, v in val.items():                          # 병합 대상 딕셔너리 순회
                    if k in merged and merged[k] != v:           # 키가 존재하고 값이 다를 때
                        merged[k] = merged[k] or v               # 둘 중 True 우선
                    else:
                        merged[k] = v                            # 없으면 그대로 추가
                base[key] = merged                                # 병합된 결과 저장
            else:
                base[key] = f"{base[key]}||{val}"                # 그 외 타입은 문자열로 변환하여 병합
    return base                                                  # 병합된 결과 반환

# 병합 처리 결과 저장용 리스트 초기화
final_data = []                      # 최종 결과 리스트
merged_log = []                      # 병합된 항목 로그 저장 리스트

# 각 서비스명 그룹에 대해 처리
for name, items in name_to_items.items():
    service_ids = {item["서비스ID"] for item in items} # 해당 서비스명의 서비스ID 집합 생성
    if len(service_ids) == 1:                         # ID가 하나면 중복이 아님
        final_data.append(items[0])                   # 그대로 추가
    else:
        merged = merge_items(items)                   # 여러 ID가 존재하면 병합 수행
        merged_log.append((name, list(service_ids)))  # 병합된 서비스명과 ID 기록
        final_data.append(merged)                     # 병합된 결과 저장

# 병합된 결과 JSON 파일로 저장
with open("data/combined_service_data_merged.json", "w", encoding="utf-8") as f:
    json.dump(final_data, f, ensure_ascii=False, indent=2) # JSON 파일로 저장

# 병합 로그 출력
print(f"✅ 최종 항목 수: {len(final_data)}개")                      # 최종 항목 수 출력
print(f"🔁 병합된 서비스 수: {len(merged_log)}개")                 # 병합된 서비스 개수 출력
for name, ids in merged_log[:10]:                               # 최대 10개 로그 출력
    print(f"🔹 서비스명: {name} / 병합된 서비스ID: {ids}")        # 서비스명과 병합된 ID 리스트 출력
# Out:
# ✅ 최종 항목 수: 8850개
# 🔁 병합된 서비스 수: 483개
# 🔹 서비스명: 양식장 친환경에너지 보급 / 병합된 서비스ID: ['502000000229', '119200000126']
# 🔹 서비스명: 수산식품 가공설비 지원 / 병합된 서비스ID: ['119200000143', '493000000110']
# 🔹 서비스명: 긴급돌봄 지원 / 병합된 서비스ID: ['135200005026', 'O00012100001']
# 🔹 서비스명: 석면피해 구제급여 지급 / 병합된 서비스ID: ['499000000113', '482000000122', '568000000104', '148000000001']
# 🔹 서비스명: 유기농업자재 지원 / 병합된 서비스ID: ['154300000014', '485000000116']
# 🔹 서비스명: 곤충산업 육성 지원 / 병합된 서비스ID: ['644000000236', '154300005006']
# 🔹 서비스명: 청년월세 한시 특별지원 / 병합된 서비스ID: ['452000000319', '161300000099']
# 🔹 서비스명: LPG용기 사용가구 시설개선 지원 / 병합된 서비스ID: ['484000000383', '174100000020', '626000000146']
# 🔹 서비스명: 임산부 건강관리 지원 / 병합된 서비스ID: ['304000000127', '567000000125', '472000000109', '300000000101']
# 🔹 서비스명: 저소득주민 국민건강보험료 지원 / 병합된 서비스ID: ['439000000833', '319000000106', '300000000102', '470000000111', '316000000121', '354000000105', '351050000109', '419000000119']

# %% [markdown]
# ### 결과 확인

# %%
# 병합된 실제 예시 출력
print("\n📌 병합된 서비스 예시 (최대 3개):\n")
for name, ids in merged_log[:3]:
    print(f"🔁 서비스명: {name}")
    print(f"📌 병합된 서비스ID 목록: {ids}\n")

    # 병합 결과 보여주기
    for item in final_data:
        if item["서비스명"] == name:
            print(json.dumps(item, ensure_ascii=False, indent=2))
            print("="*80)
            break
# Out:
# 📌 병합된 서비스 예시 (최대 3개):
#
# 🔁 서비스명: 양식장 친환경에너지 보급
# 📌 병합된 서비스ID 목록: ['502000000229', '119200000126']
#
# {
#   "구비서류": "1. 사업신청 시설부지 및 생산시설이 자가 소유인 경우\r\n    ① 부동산 등기부 등본(토지) 1통\r\n    ② 부동산 등기부 등본(시설물 또는 건축물) 1통\r\n2. 사업신청 시설부지가 임차인 경우(시설물은 반드시 자가 소유이어야 함)\r\n    ① 임대인과 임차인의 인감증명서가 각각 1통씩 첨부된 장기임대차계약서 사본 1부.\r\n    ② 부동산 등기부 등본(토지) 1통\r\n    ③ 부동산 등기부 등본(시설물 또는 건축물) 1통\r\n    ④ 임대인과 임차인의 인감증명서가 각각 1통씩 첨부된 임대차 관련 분쟁금지 확약서 1부[별지 제8호서식]\r\n\r\n<공통사항>\r\n  1. 설치 대상지의 지적도, 토지이용계획확인원 각 1부\r\n  2. 사업비가 10억원 이상인 경우 과거 3년간 경영상태를 알 수 있는 경영장부 또는   경영일지(제출이 불가능 한 경우 신용조사기관의 신용조사회보서 제출)\r\n  3. 대출 취급기관에서 대출 가능액을 확인할 수 있는 서류 제출(대출확인가능 서류 및 최근 1개월 주거래은행 금융거래 확인서, 잔고증명서 등)\r\n  4. 수출납품에 참여하는 어가 또는 법인체인 경우 수출참여 기간 동안 수출납품계약서 사본 또는 확인서(수출입조합 또는 수출업체 등) 1부. \r\n  5. 지하수를 열원으로 사용하려는 경우 지하수 개발·이용 신고(허가)서류 제출||None||None",
#   "문의처": "포항시 수산정책과/054-270-2745||해양수산부 어촌양식정책과/044-200-5392",
#   "법령": "수산업ㆍ어촌 발전 기본법(제26조)||수산업ㆍ어촌 발전 기본법(제26조의0, 제0항)||신에너지 및 재생에너지 개발ㆍ이용ㆍ보급 촉진법(제10조의0, 제0항)||신에너지 및 재생에너지 개발ㆍ이용ㆍ보급 촉진법(제9조)||신에너지 및 재생에너지 개발ㆍ이용ㆍ보급 촉진법(제9조의0, 제0항)||에너지이용 합리화법(제14조의0, 제0항)||에너지이용 합리화법(제3조)||에너지이용 합리화법(제3조의0, 제0항)",
#   "서비스ID": "119200000126||502000000229",
#   "서비스명": "양식장 친환경에너지 보급",
#   "서비스목적": "신재생에너지 이용기술을 활용한 에너지절감시설을 양식어가에 보급하고, 에너지의 효율적 이용을 통해 친환경 녹색성장을 선도하며, 에너지 이용비용 절감 등으로 어가 경영 안정을 도모||None||None",
#   "선정기준": "○ 에너지절감시설의 설치를 위한 시설 토지를 확보할 수 있어야 함\r\n   - 시장‧군수·구청장은 사업대상자가 필요면적을 사업 착수(위수탁협약) 전까지 확보하지 못하는 경우에는 사업대상자에서 제외\r\n   - 시설부지는 신청자 소유의 토지를 원칙으로 하나 부지를 확보하지 못한 경우 5년 이상 해당 토지 임대계약서 또는 토지사용승낙서를 첨부하여 신청 가능\r\n      * 시설물은 반드시 자가 소유이어야 함\r\n   - 지자체 및 한국농어촌공사의 현장조사결과 토지의 경계를 명확히 할 필요가 있을 경우, 사업신청자는 현황측량 성과도를 첨부하여 신청서류 보완\r\n      * 사업신청자는 에너지절감시설을 설치하기 위한 토지를 소음, 진동 등 주변 환경 및 토지경계 등의 문제가 없도록 확보하여야 함.\r\n\r\n○ 에너지절감시설(히트펌프)은 해수·담수 직(간)접이용 양식시설로서 수조 전체 환수량 100㎥/일 이상 또는 水(수)면적 300㎡이상인 시설.\r\n     * 단, 위 (수)면적 기준을 만족하더라도 지자체는 반드시 히트펌프 열원 확보 여부를 판단하여 지원을 결정하여야 함\r\n○ 에너지절감시설은 아래와 같은 제품으로 지원\r\n  <지열원 히트펌프 적용 기준>\r\n   - 한국에너지공단 신재생에너지센터의 신재생에너지설비(KS) 인증을 받은 제품\r\n    - 한국농기계공업협동조합으로부터 품질보증을 받은 제품\r\n   <수열원 히트펌프 적용 기준>\r\n   - 한국냉동공조인증센터 등 공인시험기관에서 한국농어촌공사의「수산분야 히트펌프 시험방법 및 성능기준」에 따른 성능인증시험을 받은 제품\r\n      * 공인시험기관 시험설비·장비의 시험한계를 초과하는 경우 현장에서 한국냉동공조인증센터의 성능시험을 받은 제품\r\n    - 한국농기계공업협동조합으로부터 품질보증을 받은 제품\r\n 다. 대상 생산물 요건\r\n ○ 에너지절감시설(히트펌프)\r\n    - 가온 또는 냉각을 필요로 하는 어류 등 양식생물\r\n\r\n※ 중복수혜불가 조건\r\n○ 사업추진 제한지역\r\n - 보조금으로 취득한 재산의 사후관리기간 연수(年數) 이내에 개발될 예정인 지역(시장‧군수·구청장은 “토지이용계획 확인원” 필히 확인)\r\n○ 사업자 선정 제외대상\r\n - 최근 2년간 사업자로 선정된 후 자부담 미납으로 인해 사업을 포기한 경우  2년간 지원 제한\r\n -「수산사업자금 집행관리 기본규정」제16조에 따라 수산정책자금 부당사용자로  지원제한 기간 미 경과자\r\n - 수산업법, 내수면어업법 등 관련법령에 따라 당해 어업의 면허, 허가 또는  신고가 취소된 자\r\n - 말라카이트 그린 등 양식시설 사용금지 물질을 의도적으로 사용한 자는「수산생물질병관리법」등 관련법령에 해당되는 불법행위 사실이 확인된 날로부터 3년간 지원 제한||None||None",
#   "소관기관명": "경상북도 포항시||해양수산부",
#   "수정일시": "2025-01-22",
#   "신청기한": "수산진흥사업 모집기간 내 ||자세한 날짜는 시군구청에 따라 다를 수 있음",
#   "신청방법": "○ 한국농어촌공사, 수산기술보급기관 등의 검토를 받아 사업신청서 및 사업계획서를 작성하여 시장‧군수․구청장에게 제출(1월)\r\n   - 사업신청서 작성 시 기온 또는 냉각부하를 산출하고 시설용량과 사업비를 결정하여 신청||ㅇ 한국농어촌공사, 수산기술보급기관 등의 검토를 받아 사업신청서 및 사업계획서를 작성하여 시장‧군수․구청장에게 제출\r\nㅇ 시청 수산정책과 및 연안 읍면사무소 방문 접수(신청)",
#   "온라인신청사이트URL": null,
#   "자치법규": null,
#   "접수기관명": "시·군·구청||None||None",
#   "지원내용": "○ 지원형태 : 국비보조 60%, 지방비 20%, 자담 20%\r\n\r\n○ 에너지절감시설(히트펌프)\r\n   - 운영에 필요한 토목공사, 천공, 그라우팅, 열교환기 및 스케일 제거장치, 히트펌프, 배관, 기존 가온․ 냉각 연계 설비, 전기 용량 증설(용량 공사비 포함, 거리공사비 제외), 제어, 시스템 보호를 위한 기계실 등 직접 영향을 미치는 설비에 한 함||지원내용\r\n  ㅇ 에너지절감시설(히트펌프)\r\n   - 가온 또는 냉각을 필요로 하는 어류 등을 양식하는 양식장의 에너지절감시설(히트펌프) 설치 지원\r\n  ㅇ 에너지절감시설(인버터)\r\n   - 해수 취수를 필요로 하는 어류 등을 양식하는 양식장의 에너지절감시설(인버터) 설치 지원",
#   "지원대상": "○ 「농어업·농어촌 및 식품산업 기본법」 및 「농어업경영체 육성 및 지원에 관한 법률」에서 규정한 어업인, 어업법인 및 수산관련 생산자단체\r\n\r\n○ 「양식산업발전법」및「내수면 어업법」에 의한 기르는 어업을 경영 중 인자 또는 경영을 하고자 하는 자\r\n    -「양식산업발전법」 및 「내수면 어업법」에 의한 양식어업(종묘생산어업, 시험어업 포함) 면허․허가(신고)를 필하거나 면허․허가(신고) 예정인 어업인, 생산자단체(수협, 어촌계, 영어조합법인, 협업 등), 유한회사 및 주식회사 등\r\n       * 개별어장을 기준으로 하되, 어촌계 등 생산자단체의 면허일 경우 단일 어장으로 간주(어촌계 등 생산자단체의 면허어장 내에 2인 이상의 지분 또는 행사자 등 경영체가 달라서 전원 동의가 되지 않는 경우에도 각 지분 또는 행사자가 경영하는 시설물에 대하여는 단일어장으로 간주)||지원대상\r\nㅇ「수산업·어촌 발전 기본법」 및 「농어업경영체 육성 및 지원에 관한 법률」에서 규정한 어업인, 어업법인 및 수산관련 생산자단체\r\nㅇ「양식산업발전법」과「종자산업육성법」에 의한 기르는 어업을 경영 중 인자 또는 경영을 하고자 하는 자\r\n    -「양식산업발전법」과「종자산업육성법」에 의한 양식어업(종자생산어업, 시험어업 포함) 면허․허가(신고)를 필하거나 면허․허가(신고) 예정인 어업인, 생산자단체(수협, 어촌계, 영어조합법인, 협업 등), 유한회사 및 주식회사 등",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 18,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "어업인": true,
#     "해당사항없음": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true,
#     "기관/단체": true
#   }
# }
# ================================================================================
# 🔁 서비스명: 수산식품 가공설비 지원
# 📌 병합된 서비스ID 목록: ['119200000143', '493000000110']
#
# {
#   "구비서류": "지원신청서 및 증빙서류 등||None||None",
#   "문의처": "해당 지자체/044-200-5486||해양수산과/061-530-5557",
#   "법령": "수산식품산업의 육성 및 지원에 관한 법률 시행령||수산식품산업의 육성 및 지원에 관한 법률 시행령(제11조)||수산업ㆍ어촌 발전 기본법(제45조)",
#   "서비스ID": "119200000143||493000000110",
#   "서비스명": "수산식품 가공설비 지원",
#   "서비스목적": "수산식품 가공설비 지원을 통해 식품분야 4차 산업과 변화하는 소비 트랜드에 대응하고 수산식품의 품질 향상 및 글로벌 경쟁력 강화||None||None",
#   "선정기준": "수산식품을 가공생산하는 개인 또는 단체 선착순 또는 공모||None||None",
#   "소관기관명": "전라남도 해남군||해양수산부",
#   "수정일시": "2025-01-16||2025-01-24",
#   "신청기한": "별도 공고기한내||상시신청",
#   "신청방법": "○ 방문 신청 \r\n - 주민센터 : 신청기간내에 관내 주소지 면사무소 방문 신청||해당 지자체 서류제출",
#   "온라인신청사이트URL": null,
#   "자치법규": "None||해남군 수산업 육성 및 해양수산사업 지원에 관한 조례",
#   "접수기관명": null,
#   "지원내용": "○ 수산식품 가공에 필요한 자동조합기 및 탈수기, 이물질선별기, 절단기, 금속검출기, 세척기, 가공생산설비 등 지원||수산식품 안전에 필요한 품질관리 및 생산성 제고를 위해 필요한 기기 개선비용 지원",
#   "지원대상": "○ 수산물 가공업체, 생산자단체 등||수산식품을 가공생산하는 개인 또는 단체",
#   "지원유형": "현금",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 18,
#     "종료": 64
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "해당사항없음": true,
#     "기관/단체": true,
#     "어업인": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
# 🔁 서비스명: 긴급돌봄 지원
# 📌 병합된 서비스ID 목록: ['135200005026', 'O00012100001']
#
# {
#   "구비서류": "- 긴급돌봄 신청은 해당 읍, 면, 동 행정복지센터로 접수 \r\n- 구비서류 : 긴급돌봄 지원사업 신청서, 개인정보 수집 및 제공 이용 동의서\r\n                    주민등록등본, 건강보험료 납부확인서 (단, 기초생활수급자와 차상위계층은 기초수급자 증명서, 차상위계층확인서로 갈음)\r\n                    대상자 증빙서류(진단서, 퇴원확인서 등)||○ 사회보장급여(사회서비스이용권) 신청서\r\n○ 사회서비스 이용자 준수사항 안내확인 동의서\r\n○ 신청 당사자의 신분증\r\n○ 진단서 등 관련 서류\r\n  * 자세한 사항은 지자체(읍·면·동)에 문의",
#   "문의처": "긴급돌봄 대표번호/1522-0365||울산광역시 복지가족진흥사회서비스원/052-243-3100",
#   "법령": "사회서비스 이용 및 이용권 관리에 관한 법률(제4조)||사회서비스 이용 및 이용권 관리에 관한 법률(제5조)||사회서비스 지원 및 사회서비스원 설립ㆍ운영에 관한 법률 시행령(제10조의1)||사회서비스 지원 및 사회서비스원 설립ㆍ운영에 관한 법률(제10조)",
#   "서비스ID": "135200005026||O00012100001",
#   "서비스명": "긴급돌봄 지원",
#   "서비스목적": "질병, 부상, 주돌봄자의 갑작스러운 부재(사망, 입원 등) 등으로 인한 돌봄 공백을 신속히 보완해 국민의 돌봄불안 해소||질병, 사고, 주돌봄자의 갑작스러운 부재 등에 대응해 신속하게 돌봄 공백을 보완, 국민의 돌봄불안을 해소",
#   "선정기준": "○ '가, 나, 다, 라'의 요건을 모두 충족하는 경우에 대상자로 선정\r\n가. 긴급성 (한시성) : 아래 ➀ ~ ➂ 요건 중 하나 만족 필요\r\n① 갑작스러운 질병 및 부상 또는 퇴원 후 한시적 돌봄 필요\r\n   - 급성기 질환(일시적 수술 등), 중증 질환 및 부상 등 발생으로 혼자 일상생활 수행이 어려워진 경우\r\n   - 병원에서 수술, 입원 치료 등을 마치고 퇴원 후 1달 이내 기간 동안 가족 등 돌볼 사람이 없는 경우\r\n     * 암, 뇌졸중, 낙상, 중증 외상 등으로 급성기 치료를 마친 후의 후유증 또는 회복기까지 요양이 필요해 혼자서 일상생활 수행이 어려운 자 \r\n\r\n② 주 돌봄자*의 갑작스러운 부재로 돌봄이 필요\r\n    * ‘주 돌봄자’란 가정 내에서 대상자를 주로 돌보던 사람을 의미하며 반드시 가족이어야만 하는 것은 아님\r\n   - 혼자 일상생활이 어려워 가족 등으로부터 돌봄을 받고 있었으나 주 돌봄자의 갑작스러운 부재가 발생한 경우\r\n   - ‘주 돌봄자’의 사망, 가출, 입원, 감염, 구금, 행방불명 등\r\n③ 타 서비스 신청 후 처리기간 또는 기타 한시적 돌봄 필요\r\n   - 노인장기요양, 장애인활동지원 등 유사 돌봄서비스를 신청하고 대기 중인 자로, 유사 돌봄서비스 대상자로 결정될 때까지 실질적으로 돌볼 사람이 없는 경우\r\n   - 기존에 보유한 만성질환, 노쇠 등 진행으로 신체기능 저하가 발생하고, 한시적 지원 필요성이 현장 방문을 통해 확인된 경우\r\n\r\n나. 돌봄 필요성\r\n ○ 혼자서는 독립적으로 일상생활 수행이 불가능하나, 돌볼 수 있는 가구원이 없는 경우(‘긴급돌봄 서비스 요구도 평가표’ 및 현장 방문으로 확인) \r\n   - 혼자서 식사하기, 옷입기, 체위변경 등 일상생활이 어려운 경우를 의미하며 질병, 수술 등의 경우에도 혼자 일상생활 수행이 가능한 자는 제외\r\n   - 돌볼 수 있는 가구원이 없는 경우는 실질적으로 동거하지 않거나 가구원이 생업에 종사하고 있어 실제적으로 돌볼 수 없는 경우를 모두 포함 \r\n\r\n다. 보충성 \r\n ○ 다른 공적 돌봄 서비스를 받고 있지 않는 경우\r\n   - 노인장기요양, 일상돌봄(기본돌봄),  가사간병 지원, 장애인활동지원, 노인맞춤돌봄(중점돌봄군), 보훈재가복지서비스, 재가의료급여 시범사업(돌봄 지원), 의료·돌봄 통합지원 시범사업,  기타 지역 자체 돌봄서비스 등을 받고 있지 않아야 함 \r\n ○ 제공할 수 있는 다른 공적 돌봄 서비스가 없는 경우\r\n   - 해당 가구에 적합한 공적 돌봄 서비스가 없어 긴급돌봄 서비스를 필요로 하는 자여야 함 \r\n\r\n라. 기타\r\n ○ (돌봄 장소) 긴급돌봄 서비스는 재가방문이 원칙이므로 재가 돌봄이 가능한 경우에 제공 \r\n ○ (연령) 돌봄이 필요한 대상자는 19세 이상인 성인을 주 대상으로 함\r\n    * 19세 미만이나, 예외적으로 긴급한 지원이 필요하다고 긴급돌봄위원회 등을 통해 인정된 경우는 서비스 제공 가능\r\n ○ (국적) 대한민국 국적을 가진 자(난민, 외국인 제외)||None||None",
#   "소관기관명": "보건복지부||재단법인울산광역시복지가족진흥사회서비스원",
#   "수정일시": "2024-10-25||2025-01-23",
#   "신청기한": "2024. 6.~12. 31.||지자체별 상이",
#   "신청방법": "○ (방문 신청) 신청자의 주민등록상 주소지의 읍·면·동 행정복지센터에 방문하여 신청\r\n○ (온라인 신청) 복지로(www.bokjiro.go.kr)에 접속하여 신청\r\n○ (전화·우편·팩스 신청) 부득이한 사유로 직접 방문이 불가할 경우, 전화, 우편, 팩스로도 신청 가능 \r\n   * 우편, 팩스 신청자는 읍·면·동에 제출 사실을 확인하여야 함\r\n○ (직권 신청) 읍·면·동 담당 공무원이 직권 신청하는 경우 신청자의 동의를 받아 신청서 대리 작성 및 제출||○ 방문접수 (방문이 어려운 경우 팩스 또는 유선으로 가능)\r\n - 읍·면·동 행정복지센터로 신청접수 \r\n - (상담 가능) 시·군·구 및 복지진흥사회서비스원",
#   "온라인신청사이트URL": "http://www.bokjiro.go.kr||None||None",
#   "자치법규": null,
#   "접수기관명": null,
#   "지원내용": "○  대상 :  질병, 부상, 주돌봄자 부재 등으로 긴급하게 돌봄이 필요한 위기상황이 발생했으나 기존 서비스로 돌봄을 받기 어려운 자\r\n  - 지원원칙\r\n   (긴급성) 갑작스러운 질병 및 부상 또는 퇴원 후 주 한시적 돌봄이 필요\r\n   (필요성) 혼자서는 독립적으로 일상생활 수행이 불가능하나, 돌볼 수 있는 가구원이 없는 경우\r\n   (보충성) 다른 공적 돌봄서비스를 받고 있지 않은 경우 \r\n○  서비스 제공장소 : 대상자 가정\r\n○ 서비스 내용 \r\n  - 재가 돌봄 : 목욕 등 신체청결, 옷 갈아입히기 등 몸단장 지원, 식사 도움, 체위변경, 안전관리 등 신체 수발지원 및 건강지원\r\n  - 가사 지원 : 청소, 설거지, 식사 준비 등 가정 내 일상생활을 위한 가정 환경 마련\r\n  - 이동 지원 : 장보기, 은행 방문 등 외출 시 동행하여 이동 지원 및 업무보조 등 제공||○ 일시적 위기상황에 대응하기 위한 한시적 재가 방문형 돌봄·가사 및 이동지원 및 방문목욕 서비스 제공\r\n  - (내용) 일정 자격을 갖춘 서비스 제공인력이 대상자의 가정을 방문해 기본돌봄 서비스(재가 돌봄, 가사·이동 지원) 및 방문목욕 서비스를 제공\r\n  - (시간) 최대 72시간의 범위 내에서 지원\r\n   * 자세한 사항은 지자체(읍·면·동, 시·군·구)에 문의",
#   "지원대상": "(긴급성, 돌봄 필요성, 보충성을 모두 충족한 자)\r\n○ 긴급성(한시성)\r\n - 갑작스러운 질병 및 부상 또는 퇴원 후 한시적 돌봄 필요\r\n - 주 돌봄자의 갑작스러운 부재로 돌봄이 필요\r\n - 타 서비스 신청 후 처리기간 또는 기타 한시적 돌봄 필요\r\n○돌봄 필요성\r\n - 혼자서는 돌깁적으로 일상생활 수행이 불가능하나, 돌볼 수 있는 가구원이 없는 경우\r\n - 다른 공적 돌봄서비스를 받고 있지 않고 제공할 수 있는 다른 공적 돌봄 서비스가 없는 경우\r\n○소득기준\r\n - 소득과 관계없이 서비스 제공이 가능하나, 건강보험료 납부 기준 중위소득에 따라 본인부담금 발생 (중위소득 160%이상은 전액 자기부담)||주 돌봄자 부재, 질병, 부상 등으로 긴급하고 일시적 돌봄 지원이 필요하나 기존 서비스로 돌봄을 받기 어려운 국민",
#   "지원유형": "서비스(돌봄)",
#   "행정규칙": null,
#   "대상연령": {
#     "시작": 0,
#     "종료": 120
#   },
#   "조건": {
#     "남성": true,
#     "여성": true,
#     "중위소득 0~50%": true,
#     "중위소득 51~75%": true,
#     "중위소득 76~100%": true,
#     "중위소득 101~200%": true,
#     "중위소득 200% 초과": true,
#     "예비부모/난임": true,
#     "임산부": true,
#     "출산/입양": true,
#     "농업인": true,
#     "어업인": true,
#     "축산업인": true,
#     "임업인": true,
#     "초등학생": true,
#     "중학생": true,
#     "고등학생": true,
#     "대학생/대학원생": true,
#     "해당사항없음": true,
#     "근로자/직장인": true,
#     "구직자/실업자": true,
#     "장애인": true,
#     "국가보훈대상자": true,
#     "질병/질환자": true,
#     "다문화가족": true,
#     "북한이탈주민": true,
#     "한부모가정/조손가정": true,
#     "1인가구": true,
#     "다자녀가구": true,
#     "무주택세대": true,
#     "신규전입": true,
#     "확대가족": true
#   }
# }
# ================================================================================
